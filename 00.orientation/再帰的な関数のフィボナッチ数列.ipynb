# %%
n = int(input("何番目の数字を求めますか？："))
import fibonacci
print(fibonacci.fibonacci(n))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 n = int(input("何番目の数字を求めますか？："))
# ----> 2 import fibonacci
#       3 print(fibonacci.fibonacci(n))
#
# ModuleNotFoundError: No module named 'fibonacci'
