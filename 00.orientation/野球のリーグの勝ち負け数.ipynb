# %%
print("team     win lose draw rate")
class Baseballteam:
    name=""
    win=0
    Lose=0
    Draw=0
    def __init__(self,name,win,lose,draw):
        self.name=name
        self.win=win
        self.Lose=lose
        self.Draw=draw
    def calc_win_rate():
        teams=[team1,team2,team3,team4,team5,team6]
        for team in teams:
             win_rate=team.win/(team.win+team.Lose)
    def show_team_result(self):
        win_rate=self.win/(self.win+self.Lose)
        print(f"{self.name:10}{self.win:2d}   {self.Lose:2d}  {self.Draw:3d} {win_rate:.3f}")
team1=Baseballteam(name="Archers",win=77,lose=64,draw=2)
team2=Baseballteam(name="Meteors",win=71,lose=69,draw=3)
team3=Baseballteam(name="Cheetahs",win=69,lose=68,draw=6)
team4=Baseballteam(name="Sharks",win=70,lose=70,draw=3)
team5=Baseballteam(name="Pythons",win=68,lose=73,draw=2)
team6=Baseballteam(name="Owls",win=59,lose=82,draw=2)
teams=[team1,team2,team3,team4,team5,team6]
for team in teams:
    team.show_team_result()
# Out:
# team     win lose draw rate
# Archers   77   64    2 0.546
# Meteors   71   69    3 0.507
# Cheetahs  69   68    6 0.504
# Sharks    70   70    3 0.500
# Pythons   68   73    2 0.482
# Owls      59   82    2 0.418
