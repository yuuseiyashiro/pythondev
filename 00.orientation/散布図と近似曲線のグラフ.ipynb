# %%
import sys
sys.path.append('path_to_matplotlib')
import matplotlib.pyplot as plt
import numpy as np
x = np.array([62, 95, 83, 100, 72, 71, 55, 85, 67, 75])   # english
y = np.array([62, 80, 85, 95, 58, 76, 52, 84, 67, 71])    # math
plt.plot(x, y, color="blue")
plt.scatter(x, y)
plt.xlabel("English")
plt.ylabel("Math")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 3
#       1 import sys
#       2 sys.path.append('path_to_matplotlib')
# ----> 3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5 x = np.array([62, 95, 83, 100, 72, 71, 55, 85, 67, 75])   # english
#
# ModuleNotFoundError: No module named 'matplotlib'
